# %% [markdown]
# # Week 11 Assignment
#
# Because I was unable to conduct our workshop this week, I'm keeping the assignment light as well.  Below you'll find just two steps for this week: one programming exercise and then a planning activity for your final project.
#
# For clarification, the "final project" I've been referring to is your "final."  It is not a project in addition to a final exam.  They're one-in-the-same.
#
# Please do the programming exercise and verify that your code works using the tests, then think about your final project and fill out the questions in the second part.
#
# ---
# ---

# %% [markdown]
# ### 47.1: Filtering and summarizing data
#
# For this work, you'll find a data file in `/data/complications_all.csv`.
#
# Read in the data file and create a variable called `mo_hospitals` that contains a data frame from the `complications_all.csv` file, filtered down to only contain those hospitals from the state of Missouri (MO).
#
# Then aggregate that data by hospital into a variable named `mo_summary`.  There are some key fields that we want to summarize:
# * We want to know the earliest date that each hospital was participating in any program
# * We want to know the latest date that each hospital stopped participating in any program
# * We want to know the total number of patients in the denominators of these programs
#
# Some things to note:
# * You will need to convert the `Start Date` and `End Date` to actual datetime fields
# * You will need to clean up and convert the `Denominator` field to just be numeric - the rule that you should use it to simply remove any records where the `Denominator` is `'Not Available'`
#
#
# The final result of this step should be a new data frame called `mo_summary` that contains one row for each hospital and contains the min start date, max end date, and total denominator.  Use the names `start_date`, `end_date`, and `number` for those columns in `mo_summary`.
#
#
# You do not need to create your code in the form of a function, just make sure your variable names match what I've described above so the tests work.

# %%
import pandas as pd
# This is just to show you the name to use for the variable you need to create for this step to pass.
mo_hospitals = pd.read_csv('/data/complications_all.csv')
filter_mo = mo_hospitals['State'] == 'MO'
mo_hospitals = mo_hospitals[filter_mo]
mo_hospitals.head()
                            
#grouped_single = mo_hospitals.groupby('Facility Name').agg({'Start Date': ['min']}, {'End Date': ['max']}, {'number': ['Denominator']})
#grouped_single.head()
# Out:
#       Facility ID          Facility Name        Address    City State  \
# 45534      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45535      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45536      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45537      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
# 45538      260001  MERCY HOSPITAL JOPLIN  100 MERCY WAY  JOPLIN    MO
#
#        ZIP Code County Name    Phone Number     Measure ID  \
# 45534     64804      JASPER  (417) 781-2727  COMP_HIP_KNEE
# 45535     64804      JASPER  (417) 781-2727    MORT_30_AMI
# 45536     64804      JASPER  (417) 781-2727   MORT_30_CABG
# 45537     64804      JASPER  (417) 781-2727   MORT_30_COPD
# 45538     64804      JASPER  (417) 781-2727     MORT_30_HF
#
#                                             Measure Name  \
# 45534  Rate of complications for hip/knee replacement...
# 45535               Death rate for heart attack patients
# ...

# %%
# These assertions will help make sure that you're on the right track.
assert(mo_hospitals['State'].unique() == ['MO'])
assert(mo_hospitals.shape == (2133,18))

# %%
# Trans mo_hospitals['Facility Name'].unique()
#mo_summary = ...
type(mo_hospitals['Start Date'])
mo_hospitals['Start Date'] = pd.to_datetime(mo_hospitals['Start Date'])
mo_hospitals['End Date'] = pd.to_datetime(mo_hospitals['End Date'])
mo_hospitals['Denominator'].dropna()
notavailable = mo_hospitals["Denominator"] == "Not Available"
mo_hospitals = mo_hospitals[~notavailable]
#mo_hospitals['Denominator'] = mo_hospitals['Denominator'].astype('int')
mo_hospitals.head()

    
# filtering data 
# displaying data only with Gender = NaN 
#mo_hospitals[notavailable] 
mo_hospitals["Denominator"] = mo_hospitals["Denominator"].astype('int')

summarycols = {'Denominator':'number', 'Start Date':'start_date','End Date':'end_date'}
mo_summary=mo_hospitals.groupby('Facility Name').agg({'Denominator':'sum', 'Start Date':'min','End Date':'max'}).rename(columns=summarycols)
mo_summary
# Out:
#                                      number start_date   end_date
# Facility Name
# BARNES JEWISH HOSPITAL               131313 2015-04-01 2018-06-30
# BARNES-JEWISH ST PETERS HOSPITAL      15668 2015-04-01 2018-06-30
# BARNES-JEWISH WEST COUNTY HOSPITAL     9622 2015-04-01 2018-06-30
# BATES COUNTY MEMORIAL HOSPITAL         3117 2015-07-01 2018-06-30
# BELTON REGIONAL MEDICAL CENTER         9270 2015-04-01 2018-06-30
# ...                                     ...        ...        ...
# TRUMAN MEDICAL CENTER LAKEWOOD         4297 2015-04-01 2018-06-30
# UNIVERSITY OF MISSOURI HEALTH CARE    56493 2015-04-01 2018-06-30
# WASHINGTON COUNTY MEMORIAL HOSPITAL     220 2015-07-01 2018-06-30
# WESTERN MISSOURI MEDICAL CENTER        7254 2015-04-01 2018-06-30
# WRIGHT MEMORIAL HOSPITAL                198 2015-07-01 2018-06-30
#
# [108 rows x 3 columns]

# %%
assert(mo_summary['number'].sum() == 1766908)
assert(mo_summary['start_date'].min() == pd.Timestamp(2015,4,1))
assert(mo_summary['end_date'].max() == pd.Timestamp(2018,6,30))
assert(mo_summary.shape == (108,3))
assert(mo_summary.loc['BARNES JEWISH HOSPITAL'].number == 131313)
assert(mo_summary.loc['BOONE HOSPITAL CENTER'].number == 63099)

# %%
mo_summary.loc['BARNES JEWISH HOSPITAL']
# Out:
# number                     131313
# start_date    2015-04-01 00:00:00
# end_date      2018-06-30 00:00:00
# Name: BARNES JEWISH HOSPITAL, dtype: object

# %% [markdown]
# ---
#
# ### 47.2 Planning your final project
#
# You should be thinking about the things we've been learning and how you can apply them to your final project.  Use the rubric to help guid your thinking and then answer the questions below.  This is meant as a guide to help you think through what you will do.

# %% [markdown]
# #### A) Data Access
#
# Your project should include data from at least three distinct types of sources.  For example: AWS S3, Relational Databases, Internet, Web Services, local files.  List what data sources you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
# The sources I intend to use are
# * Kaggle - psychiatric disorders
#     - https://www.kaggle.com/datasets/shashwatwork/eeg-psychiatric-disorders-dataset (csv)
# * Kaggle - suicide watch
#     - https://www.kaggle.com/datasets/nikhileswarkomati/suicide-watch
# * Kaggle - depression
#    - https://www.kaggle.com/datasets/arashnic/the-depression-dataset
# * Mental health in tech 2016
#    - https://www.kaggle.com/datasets/osmi/mental-health-in-tech-2016
# * Mental health in the tech industry 2016
#    - https://www.kaggle.com/datasets/osmi/mental-health-in-tech-2016
# * Mental health in tech
#    - https://www.kaggle.com/datasets/anth7310/mental-health-in-the-tech-industry
# * SDOH Data
#    - Some data from a website such as https://nccd.cdc.gov for a SDOH data set
# * Wikipedia (html)
#    - https://en.wikipedia.org/wiki/Classification_of_mental_disorders
#
#
# I am confident I will use 3 of the several above listed sourced to do some analysis on the topic of mental health. I plan to use the wikipedia link to do a lookup of the various mental health disorders
# I will definitely use
# * csv
# * html
# * I will upload an existing csv to google cloud bigquery OR a google cloud gcs bucket for variety in sources of data.

# %% [markdown]
# #### B. Data Formats
#
# Your project should include data that comes in different file formats.  For example: HL7, EDI, HTML, CSV, Excel, JSON, XML.  List what data formats you're planning to use.

# %% [markdown]
# **Double-click to enter your answer**
#
#
# * CSV
# * HTML

# %% [markdown]
# #### C. Objective
#
# What purpose would your project serve in a real work setting?  Take a couple of paragraphs to write down why this is an interesting product.

# %% [markdown]
# **Double-click to enter your answer**
#
#
# Mental health is a significant problem today with more awareness than it ever had. However whether it is sufficient is a looming question.
# As per this link https://www.nami.org/mhstats
# "Millions of people in the U.S. are affected by mental illness each year. It’s important to measure how common mental illness is, so we can understand its physical, social and financial impact — and so we can show that no one is alone. These numbers are also powerful tools for raising public awareness, stigma-busting and advocating for better health care."
#
# Assuming I find data I am looking for my project will analyse
# * Mental disorder detection rates
# * Suide rates
# * Intervention methods and government spend on intervention.
#
# I want to study whether overall as a society we are progressing in the right direction or not.
# The real world problem this will solve if nothing else is
# * Awareness of all these aspects.
#
# Aware and data driven decision making can then be used to
# * Fund more programs for early detection and intervention at various points of opportunity (school/work etc)

# %% [markdown]
# ---
#
#
#
# ## Submitting Your Work
#
# In order to submit your work, you'll need to use the `git` command line program to **add** your homework file (this file) to your local repository, **commit** your changes to your local repository, and then **push** those changes up to github.com.  From there, I'll be able to **pull** the changes down and do my grading.  I'll provide some feedback, **commit** and **push** my comments back to you.  Next week, I'll show you how to **pull** down my comments.
#
# To run through everything one last time and submit your work:
# 1. Use the `Kernel` -> `Restart Kernel and Run All Cells` menu option to run everything from top to bottom and stop here.
# 2. Follow the instruction on the prompt below to either ssave and submit your work, or continue working.
#
# If anything fails along the way with this submission part of the process, let me know.  I'll help you troubleshoort.

# %% [markdown]
# ---

# %%
a=input('''
Are you ready to submit your work?
1. Click the Save icon (or do Ctrl-S / Cmd-S)
2. Type "yes" or "no" below
3. Press Enter

''')

if a=='yes':
    # !git add week11_assignment_2.ipynb
    # !git commit -a -m "Submitting the week 11 programming assignment"
    # !git push
else:
    print('''
    
OK. We can wait.
''')
# Out:
# Are you ready to submit your work?
# 1. Click the Save icon (or do Ctrl-S / Cmd-S)
# 2. Type "yes" or "no" below
# 3. Press Enter
#
#  yes
# [main a80d2ee] Submitting the week 11 programming assignment
#  2 files changed, 686 insertions(+), 3 deletions(-)
#  create mode 100644 week11/week11_assignment_2.ipynb
# ...
# Counting objects: 5, done.
# Delta compression using up to 2 threads.
# Compressing objects: 100% (5/5), done.
# Writing objects: 100% (5/5), 6.49 KiB | 6.49 MiB/s, done.
# Total 5 (delta 2), reused 0 (delta 0)
# remote: Resolving deltas: 100% (2/2), completed with 2 local objects.
# To github.com:rasalt/hds5210-2022.git
#    171fc9b..a80d2ee  main -> main
